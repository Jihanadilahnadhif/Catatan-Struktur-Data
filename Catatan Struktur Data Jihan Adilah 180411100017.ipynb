# %%
Assalamualaikum Warohmatullohi Wabarokatuh

# %% [markdown]
# A. SEARCHING

# %%
   
    A.1 #LINEAR SEARCH
    
        adalah salah satu algoritma untuk mencari data yang berada dalam sebuah data yang tertata. 
Proses dari linear search yaitu mencari data dari salah satu ujung kiri/kanan lalu mencari tiap data 
secara runtut sampai ketemu data yang dinginkan.

# %%
#Contoh Linear 1
search=2
mylist=[1,2,3,4,5,6]
position=0
last=len (mylist) -1
middle=(position+last)/2
found=False
while position <= last and not found :
    if mylist[middle]==search:
        found=True
    else:
        if mylist[middle]<= search:
            middle=middle-1
        else:
            position=middle+1
    if found:
        print ("found the search number:")
        print (position)
    else:
        print ("didnt found the number")

# %%
#Contoh Linear 2
def linearSearch(item,my_list):
    found = False
    position = 0
    while position < len(my_list) and not found:
        if my_list[position] == item:
            found = True
        position = position + 1
    return found

# %%
#Contoh Linear 3
def sequentialSearch(alist,item):
    pos = 0
    found = False
    
    while pos < len(alist) and not found:
        if alist[pos] == item:
            found = True
        else:
            pos = pos + 1
    return found
testlist = [1,2,32,8,17,19,42,13,0]
print(sequentialSearch(testlist,3))

# %%
############################ T U G A S - P R A K T I K U M - 1 ############################
Tugas Praktikum 1 : Linear Search / Sequential Search
1.	Input : [15, 18, 2, 19, 18, 0, 8, 14, 19, 14]
Proses : algoritma Linear Search 
Pertanyaan : Berapa jumlah interasi yang dilakukan untuk mencari bilangan 8? 
    Dan berapa iterasi yang dilakukan utuk mencari angka 7

2.	Input : sama dengan soal no 1 hanya saja dalam kondisi terurut
Proses : algoritma Linear Search (sama seperti soal no 1)
Pertanyaan : Berapa jumlah interasi yang dilakukan untuk mencari bilangan 8?
    Dan berapa iterasi yang dilakukan utuk mencari angka 7

3.	Input : sama dengan soal no 1 hanya saja dalam kondisi terurut
Proses : algoritma Linear Search dengan dilakukan modifikasi 
    jika bilangan yang dicari tidak ada dalam list dan bilangan tersebut lebih kecil dari deretan bilangan input 
    maka proses iterasi stop.
Pertanyaan : Berapa jumlah interasi yang dilakukan untuk mencari bilangan 8? 
    Dan berapa iterasi yang dilakukan utuk mencari angka 7
Analisa ketiga pertanyaan diatas.
Soal ke 4
-	Buat algortima sorting (bebas), inputkan sejumlah bilangan bebas, 
lakukan sorting terlebih dahulu kemudian proses selanjutnya gunakan algortima searching moddifikasi (soal no ), 
cari bolangan yang ada dan tidak ada dalam list. Bagaimana proses iterasinya?

# %%
#TP 1 (N0 1)

a = [15, 18, 2, 19, 18, 0, 8, 14, 19, 14]
print(a)
cari = int(input("masukkan angka : "))
posisi = 0
iterasi = 0
akhir = len(a) - 1
found = False
for posisi in range (akhir) :
    iterasi = iterasi + 1
    if a[posisi] == cari :
        found = True
        break
    else :
        posisi = posisi + 1
if found :
    print("angka yang dicari terletak pada indeks : ", posisi)
    print("iterasi sebanyak = ", iterasi, "kali")
else :
    iterasi = iterasi + 1
    print("angka tidak ditemukan")
    print("iterasi sebanyak = ", iterasi, "kali")

# %%
#TP 1 (NO 2)
angka = [15, 18, 2, 19, 18, 0, 8, 14, 19, 14]
iterasi = 0
akhir = len(angka) - 1
angka.sort()
print(angka)
cari = int(input("masukkan angka : "))
posisi = 0
found = False
for posisi in range (akhir) :
    iterasi = iterasi + 1
    if angka[posisi] == cari :
        found = True
        break
    else :
        posisi = posisi + 1
if found :
    print("angka yang dicari terletak pada indeks : ", posisi)
    print("iterasi sebanyak = ", iterasi, "kali")
else :
    iterasi = iterasi + 1
    print("angka tidak ditemukan")
    print("iterasi sebanyak = ", iterasi, "kali")

# %%
#TP 1 (NO 3)
angka = [15, 18, 2, 19, 18, 0, 8, 14, 19, 14]
akhir = len(angka) - 1
angka.sort()
print (angka)
cari = int(input("masukkan angka : "))
posisi = 0
iterasi = 0
found = False
henti = False
for posisi in range (akhir) :
    iterasi = iterasi + 1
    if angka[posisi] == cari :
        found = True
        break
    elif angka[posisi] > cari :
        henti = True
        break
    else :
        posisi = posisi + 1
    
        
if found :
    print("angka yang dicari terletak pada indeks : ", posisi)
    print("iterasi sebanyak = ", iterasi, "kali")
else :
    print("angka tidak ditemukan")
    print("iterasi sebanyak = ", iterasi, "kali")
    print("angka tersebut lebih kecil dari deretan bilangan input setelahnya")

# %%
# TP 1 (N0 4)
angka = []
b = int(input("jumlah list : "))
c = 0
for x in range (b) :
    c = c + 1
    d = int(input())
    print("masukkan angka ke - ", c, " : ",d)
    angka.append(d)
for i in range ((b-1),0,-1) :
    for y in range (i) :
        if angka[y] > angka[y+1] :
            a = angka[y]
            angka[y] = angka[y+1]
            angka[y+1] = a
print (angka)
cari = int(input("masukkan angka : "))
posisi = 0
iterasi = 0
found = False
henti = False
for posisi in range (b-1) :
    iterasi = iterasi + 1
    if angka[posisi] == cari :
        found = True
        break
    elif angka[posisi] > cari :
        henti = True
        break
    else :
        posisi = posisi + 1
    
        
if found :
    print("angka yang dicari terletak pada indeks : ", posisi)
    print("iterasi sebanyak = ", iterasi, "kali")
else :
    print("angka tidak ditemukan")
    print("iterasi sebanyak = ", iterasi, "kali")
    print("angka tersebut lebih kecil dari deretan bilangan input setelahnya")

# %%
        A.2 #Binary Search
    
     Binary Search adalah algoritma pencarian data dengan mengurutkan data terlebih dahulu secara ascending/descending. 
Setelah data diurutkan akan mencari data tengah terlebih dahulu. 
Apabila data yang dicari kurang dari data tengah, maka pencarian data dimulai dari index ke 0 sampai index sebelum data tengah.
Sedangkan apabila data yang dicari lebih dari data tengah, 
maka pencarian data dimulai dari index setelah data tengah sampai index terakhir. 
Begitu seterusnya sampai data yang dicari tersebut ditemukan.

# %%
#Contoh Binary Search 1
def binary_search(angka,listku):
  listku.sort() #Penyortiran List
  langkah = 0
  ketemu = False
  awal = 0
  akhir = len(listku)-1
  while awal <= akhir and not ketemu:
    tengah = (awal+akhir)//2
    if listku[tengah] == angka:
      ketemu = True
    elif angka > tengah:
      awal = tengah+1
    else:
      akhir = tengah-1
    langkah+=1
  if ketemu:
    print ("Angka ditemukan!")
    print ("posisi angka yang ditemukan adalah %s" % str(awal+1))
  else:
    print ("Angka yang anda maksudkan tidak ditemukan!")
  print ("Langkah yang sudah di ambil dalam menemukan adalah %s langkah" % langkah)

binary_search(3,[1,1,2,6,7,8,9,3,4])

# %%
#Contoh Binary Search 2

def deret(search,list):
    first=0
    last=len(list)-1
    found=0
    
    while first<=last and not found:
        middle= (first+last)//2
        if list [middle]==search:
            found=1
        else:
            if search<list[middle]
                last=middle-1
            else:
                first=middle+1
        if found:
            print ("found the search number")
            print (middle)
        else:
            print ("didnt find the search number")

# %%
#Contoh Binary Search 3

search = 1
myList = [3, 1, 4, 4, 5, 6]
myList.sort()
first = 0
last = len(myList)-1
found = False

while first <= last and not found:
  middle = (first + last) // 2
  if myList[middle] == search:
	  found = True
  else:
    if search < myList[middle] :
      last = middle - 1
    else:
      first = middle +1
if found:
	print("Found the search number.")
	print(middle)
else:
	print("Did not find the search number.")

# %%
B. HASHING

# %%
        Hashing adalah teknik atau metode memetakan data ke sebuah tempat dimana data sebenarnya dirubah dalam bentuk lain.
    semisal huruf a menjadi huruf e.
    Teknik ini biasanya digunakan untuk mengenkrispsi sebuah password didalam database seperti MySQL. 
Pada python, cara metode Hashing dengan membuat sebuah List yang akan diisi oleh data masukan. 
Data masukan diberi 2 buah nilai yaitu value sebagai data tersebut dan juga key sebagai alat untuk memasukan value ke List.

# %%
        
    # B.1 LINEAR HASHING
            Penyelesaian dengan linear yaitu melakukan penambahan 1 tiap index yang terjadi collision,
    misalnya, collison terjadi pada index 3, maka data selanjutnya yang berindex 3 akan ditambahkan ke index 4,
    jika index 4 sudah terdapat value atau isi maka data terdebut ditaruh di index 5.

# %%
# Contoh Linear Hashing 1

table = [None] * 11

def hash(x):
  return x % 11

def insert(table,key,value):
  index = hash(key)
if table[index] == None:
    table[index] = value
  else :
    collusion=index

    found = False
    ind=collusion+1
    if ind>= len(table)-1:
        ind = 0
    while (ind<=len(table)-1) and not(found):
        if table[ind]== None:
            found=True
            table[ind]=value
       ind=ind+1

print(table)
insert(table,54,54)
print(table)
insert(table,26,26)
print(table)
insert(table,93,93)
print(table)
insert(table,17,17)
print(table)
insert(table,77,77)
print(table)
insert(table,31,31)
print(table)
insert(table,44,44)
print(table)
insert(table,55,55)
print(table)
insert(table,20,20)
print(table)
insert(table,25,25)
print(table)

# %%
    
        B.2 #Aquadratic Hashing
        
        Penyelesaian dengan Quadratic/Aquadratic ini sama seperti linear akan tetapi penambahan tidak satu persatu, 
    melainkan penambahnya di kuadratkan lalu dimodulus dengan panjang tabel hash.
Misalnya yang terjadi collison pada index 3 dan panjang tabel hash 10 maka jika ditambahkan data yang berindex 3 
maka data terbut ditaruh pada index ke 3 yang ditambah 1 kuadrat 2 jadi berindex 4 lalu dimodulus panjang tabel hash j
adi index 4. Jika index 4 sudah terisi maka index ditambah 2 kuadrat 2 jadi 3+4 yaitu 7 dan dimodulus panjang tabel hash
yaitu 10 menjadi index 7, begitu seterusnya hingga data dapat ditempakan ditempat kosong pada tabel hash.

# %%
# Contoh Quadratic Hashing 1
table = [None] * 11
def hash(x):
  return x % 11


def insert(table,key,value):
  index = hash(key)
  if table[index] == None:
    table[index] = value
  else:
    collusion=index
    found = False
    i=1
    ind = collusion+1

    if ind > len(table)-1:
        ind = 0

    while (ind<=len(table)-1) and not(found):
      if table[ind]== None:
        found=True
        table[ind]=value
        ind = (collusion+(i*i)) % 11
      i=i+1

print(table)
insert(table,54,54)
print(table)
insert(table,26,26)
print(table)
insert(table,93,'93')
print(table)
insert(table,17,'17')
print(table)
insert(table,77,'77')
print(table)
insert(table,31,'31')
print(table)
insert(table,44,'44')
print(table)
insert(table,55,'55')
print(table)
insert(table,20,'20')
print(table)

# %%
    
        B.3 #Chainning
        
            Penyelesaian dengan cara Chainning yaitu membuat list didalam tabel hash 
        sehingga data yang berindex sama tidak terjadi collison karena data tersebut ditumpuk ke dalam sebuah list yang
        telah dibuat.

# %%
#Contoh Chainning 1
print('============= Program Hashing Data Numerik (Chaining Probbing) ================ ')
l = 'y'
while l == 'y':
    table = int(input('Masukan panjang tabel Hash = '))
    table = [ [] for _ in range(table) ]

    def hash(x,table):
        return x % len(table)

    def insert(table,key,value):
        table[hash(key,table)].append(value)

    #Jika ingin mencari data dengan hasil True dan False
    '''def searchHash(data,table):
        found = False
        i = 0
        j = 0
        while i < len(table) and not found:
            if data in table[i]:
                print('Data ditemukan')
                found = True
            i+=1
        if found == False:
            print('Data tidak ditemukan')'''
    #Jika ingin mencari data dengan hasil index data yang dicari
    '''def searchHash(data,table):
        found = False
        i = 0
        
        while i < len(table) and not found:
            j = 0
            while j < len(table[i]) and not found:
                if data == table[i][j]:
                    found = True
                if found==False:
                    j+=1
            if found==False:
                i+=1
        if found == True:
            print('Data %s berada pada list ke-%s index ke-%s'%(data,(i+1),j))
        else:
            print('Data %s tidak ditemukan'%data)'''

    def searchHash(data,table):
        index = hash(data,table)
        if data in table[index]:
            print('True')
            jml = len(table[index])
            for i in range(jml):
                if data == table[index[i]]:
                    break
            print('Data %s berada di dalam list %s index %s'%(data,index,i))
        else:
            print('Data %s tidak ditemukan'%data)

    
    nginput = int(input('Masukan berapa kali ingin memasukan data ke Tabel Hash = '))
    b = 1
    while b<=nginput:
        masukan = int(input('Masukan angka yang ingin dimasukan ke Tabel Hash = '))
        insert(table,masukan,masukan)
        b+=1

    print(table)
            
    nginput = True
    while nginput:
        q = input('Apakah ingin mencari Data ? (y/n) ')
        if q == 'y':
            dicari = int(input('Masukan angka yang ingin dicari = '))
            searchHash(dicari,table)
        elif q == 'n':
            nginput = False
        else:
            print('Masukan y atau n!')
            nginput = True

    k = 'y'
    while k =='y':
        l = input('Apakah ingin melanjutkan program ? (y/n) ')
        if l == 'y':
            k = 'n'
        elif l == 'n':
            print('Terima Kasih')
            k = 'n'
        else:
            print('Masukan y atau n!')
            k = 'y'

# %%
############################ T U G A S - P R A K T I K U M - 2 ############################

1.	Modifikasi source code program Hashing, untuk mencari data dalam sebuah table hashing. 
Jika data tersebut ada maka lakukan remove item data tersebut. 
Jika data tersebut tidak ada lakukan insert item pada data tersebut.
Modifikasi souce code program ini ada 3 bentuk

a.	Linear Probbing
b.	Quadratic Probbing
c.	Chaining (Close Address)

2.	Implementasikan algoritma modifikasi binary search berikut ini

Low – the lowest index in the array 
High- highest index in the array 
Middle – middle element’s index in the array 
X – element to be searched

# %%
# TP 2 (NO 1 LINEAR HASHING)
#proses hashing
table = int(input("panjang tabel hash : "))
table = [None] * table
print(table)
def hash(x,table):
    return x % len(table)

def insert(table,key,value):
    index = hash(key,table)
    if table[index] == None:
        table[index] = value
    else:
        collusion = index
        found = False
        ind = collusion + 1
        if ind > len(table) - 1:
                ind = 0
        while (ind <= len(table)-1) and not found:
            if table[ind] == None:
                found = True
                table[ind] = value
            ind = ind + 1

a = "y"
while a == "y" :
    jumlah = int(input("jumlah angka yang ingin dimasukkan : "))
    if jumlah > len(table):
        print("jumlah angka yang dimasukkan terlalu panjang")
        print("masukkan lagi")
    else :
        a = "t"

#untuk memasukkan angka
angka = []
for p in range (jumlah):
    masukan = int(input("Masukan angka = "))
    insert(table,masukan,masukan)
    p = p + 1
    angka.append(masukan)
print(angka,
      "<<<<<<<<<<<<< tabel sebelum hashing")
print(table,
      "<<<<<<<<<<<<< tabel setelah Hashing")

#mencari angka
cari = int(input("masukkan angka yang ingin dicari : "))
posisi = 0
henti = False
for posisi in range (len(table) - 1) :
    if table[posisi] == cari :
        henti = True
        break
    else :
        posisi = posisi + 1

#remove and insert item
if henti == True :
    for posisi in range (len(table)) :
        if cari == table[posisi] :
            table[posisi] = "None"
    print(table)
    print("angka yang dicari : ", cari)
    print("angka yang anda cari telah dihapus dari dalam tabel")
else :
    table.append(cari)
    print("angka yang ingin dimasukkan : ", cari)
    print(table)
    print("angka telah masuk kedalam tabel")

# %%
# TP 2 (N0 2 QUADRATIC)
table = int(input("panjang tabel hash : "))
table = [None] * table
print(table)

def hash(x,table):
    return x % len(table)

def insert(table,key,value):
    index = hash(key,table)
    if table[index] == None:
        table[index] = value
    else:
        collusion = index
        found = False
        i = 1
        while i > 0 and not found :
            ind = collusion + i**2
            ind = ind % len(table)
            if table[ind] == None :
                found = True
                table[ind] = value
            i = i + 1

#untuk menginputkan jumlah angka
a = "y"
while a == "y" :
    jumlah = int(input("jumlah angka yang ingin dimasukkan : "))
    if jumlah > len(table):
        print("jumlah angka yang dimasukkan terlalu panjang")
        print("masukkan lagi")
    else :
        a = "t"

#untuk memasukkan angka
angka = []
for p in range (jumlah):
    masukan = int(input("Masukan angka = "))
    insert(table,masukan,masukan)
    p = p + 1
    angka.append(masukan)
print(angka,
      "<<<<<<<<<<<<< tabel sebelum hashing")
print(table)

#mencari angka
cari = int(input("masukkan angka yang ingin dicari : "))
posisi = 0
henti = False
for posisi in range (len(table) - 1) :
    if table[posisi] == cari :
        henti = True
        break
    else :
        posisi = posisi + 1

#remove and insert item
if henti == True :
    table.remove(cari)
    print(table)
    print("angka yang dicari : ", cari)
    print("angka yang anda cari telah dihapus dari dalam tabel")
else :
    table.append(cari)
    print("angka yang ingin dimasukkan : ", cari)
    print(table)
    print("angka telah masuk kedalam tabel")

# %%
# TP 2 (NO 3 CHAINING) 
table = int(input("panjang tabel hash : "))
table = [[] for i in range(table)]
print(table)

def hash(x,table):
    return x % len(table)

def insert(table,key,value):
    table[hash(key,table)].append(value)
    
#untuk menginputkan jumlah angka
a = "y"
while a == "y" :
    jumlah = int(input("jumlah angka yang ingin dimasukkan : "))
    if jumlah > len(table):
        print("jumlah angka yg ingin dimasukkan terlalu panjang")
        print("masukkan lagi")
    else :
        a = "t"

#untuk memasukkan angka
angka = []
for p in range (jumlah):
    masukan = int(input("Masukan angka = "))
    insert(table,masukan,masukan)
    p = p + 1
    angka.append(masukan)
print(angka,
      "<<<<<<<<<<<<< tabel sebelum hashing")
print(table)

#mencari angka
cari = int(input("masukkan angka yang ingin dicari : "))
posisi = 0
henti = False
#remove and insert item
if cari in table[posisi] :
    for j in range (table[posisi].count(cari)) :
        table[posisi].remove(cari)
else :
    table.append(cari)
print(table)

# %%
#TP 2 (N0 4 BINARY SEARCH)
def search(X,a) :
    low = 0
    high = len(a) - 1
    ketemu = False
    while low < high and not ketemu :
        mid = (low + high )//2
        if a[low] > X or a[high] < X :
            print("angka tidak ditemukan")
        else :
            if a[low] == X  :
                ketemu = True
                return print("indeks ke : ",low)
            elif a[high] == X :
                ketemu = True
                return print("indeks ke : ",low)
            elif a[mid] == X :
                ketemu = True
                return print("indeks ke :  ",low)
            elif a[mid] > X :
                high = mid - 1
            else :
                low = mid + 1
    
a = [1,1,2,6,7,8,9,3,4]
a.sort()
print(a)
X = int(input("masukkan angka : "))
search(X,a)

# %%
C. SORTING

# %%
        
    C.1 # Bubble Sort
    
            Bubble Sort adalah salah satu algoritma pengurutan data dengan ascending/descending yang paling sederhana. 
    Algoritma ini bekerja dengan menukarkan data dengan data sebelahnya kemudian data sebelahnya 
    diurutkan dengan sebelahnya lagi secara terus menerus dalam satu iterasi.

# %%
#Contoh Bubble Sort 1
def sorting (data):
    for i in range (0,len(data)-1:
        for j in range(0,len(data)-1):
            if data[j]<data[j+1]
            temp = data[j]
            data[j+1]=temp

panjang=int(input("masukkan panjang list= "))
myList=[0]*panjang
for x in range (panjang):
    mylist[x]=int(input("masukkan angka= "))

sorting(mylist)
print(myList)

#tanpa function
data=[1,8,44,6]
for i in range(0,len(data)-1):
    for j in range(0,len(data)-1:
        if data[j]<data[j+1]:
            temp = data[j]
            data[j] = data[j+1]
            data [j+1] = temp
print(data)

#mengkalkulasi berapa kali interasi yang dilakukan
data=[1,8,44,6]
for i in range(0,len(data)-1):
    for j in range (0,len(data)-1:
        if data[j]<data[j+1]:
            temp = data[j]
            data[j] = data[j+1]
            data[j+1]=temp

# %%
#Contoh Bubble Sort 2

lst = [5,0,1,10,7,2,5,4,6,9]
print(lst)
for k in range(1,len(lst)):
    for i in range(0,len(lst)-1):
        if lst[i]>lst[i+1]:
            lst[i],lst[i+1] = lst[i+1],lst[i]
print(lst)

# %%
#Contoh Bubble Sort 3
lst = [4,7,1,9,3,10,6]
print(lst)
for i in range(0,len(lst)-1):
    min=i
    for j in range(i+1,len(lst)):
        if lst[j]<lst[min]:
            min = j

    lst[i],lst[min]=lst[min],lst[i]
print(lst)

# %%
        
        C.2 # Insertion Sort
        
            Insertion Sort adalah algoritma/metode pengurutan yang membandingkan dua elemen pertama, 
        mengurutkannya, kemudian mengecek elemen data berikutnya satu persatu
        dan membandingkannya dengan elemen data yang telah diurutkan. 
        Ide algoritma ini seperti kartu yang sedang diurutkan,
        misalnya kartu pertama di geser ke kedua maka kartu selanjutnya juga ikut mundur

# %%
# Contoh Insertion Sort 1
lst = [4,7,1,0]

for i in range(1,len(lst)):
    nilaiawal = lst[ i]
    hole = i
    while lst[hole-1] > nilaiawal and hole > 0   :
        lst[hole] = lst[hole-1]
        hole=hole-1

    lst[hole] = nilaiawal

print(lst)

# %%
    
        C.3 # Quick Sort
    
    Quick Sort adalah salah satu algoritma pengurutan data yang paling cepat, 
yaitu dengan membagi list menggunakan sebuah pivot.
Quick Sort juga menggunakan rekursif dalam algoritmanya.
    Misalnya jika pengurutannya secara ascending, data yang kurang dari pivot sudah ditentukan
    ditaruh disebelah kirinya pivot sedangkan data yang lebih besar dari pivot maka ditaruh disebelah kanan pivot. 
    Setelah dipisah, bagian-bagian yang sudah dipisah melakukan pembagian seperti sebelumnya karena ini 
    sehingga Quick Sort menggunakan rekursif.
    Begitu seterusnya sampai data terurut.

# %%
#Contoh Quick Sort 1
def QuickSortAwal(A):
    QuickSort(A,0,len(A)-1)
def QuickSort(A,start,end):
        if start<end:
            pIndex = Partition(A,start,end)
            QuickSort (A,start,pIndex-1)
            QuickSort(A,pIndex+1,end)

def Partition(A,start,end):
    pivot = A[end]
    pIndex = start
    for i in range(start,end):
        if (A[i] <= pivot):
            A[i],A[pIndex]=A[pIndex],A[i]
            pIndex=pIndex+1
        A[pIndex],A[end]=A[end],A[pIndex]
        return pIndex

A=[100,6,500,4,56,2,1,0]
QuickSortAwal(A)
print(A)

# %%
#Contoh Quick Sort 2
def Partition(A,start,end):
    pivot = A[end]
    pIndex = start
    for i in range(start,end):
        if (A[i] <= pivot):
            A[i],A[pIndex]=A[pIndex],A[i]
            pIndex=pIndex+1
    A[pIndex],A[end]=A[end],A[pIndex]
    return pIndex
def QuickSort(A,start,end):
    if start<end:
        pIndex = Partition(A,start,end)
        QuickSort (A,start,pIndex-1)
        QuickSort (A,pIndex+1,end)

# %%
#Contoh Quick Sort 3
def quickSorttengah(alist):
    quickSortHelper(alist,0,len(alist)-1)

def quickSortHelper(alist,first,last):

    if first<last:
        splitpoint = partition(alist,first,last)
        quickSortHelper(alist,first,splitpoin-1)
        quicSortHelper(alist,splitpoint+1,last)

def partition(alist,first,last):

    tengah = (first+last)//2
    pivotvalue = alist.pop(tengah)
    leftmark = first
    rightmark = last-1
    done = False
    while not done :
        while leftmark <= rightmark and alist[leftmark] <= pivotvalue:
            leftmark = leftmark + 1
        while alist[rightmark] >= pivotvalue and rightmark >= leftmark:
            rightmark= rightmark -1
        if rightmark < leftmark:
            done = True
        else:
            temp = alist[leftmark]
            alist[leftmark] = alist[rightmark]
            alist[rightmark] = temp
    alist.insert(leftmark,pivotvalue)
    print(alist,pivotvalue)
    return leftmark

alist = [5,1,4,2,8,10,3]
quickSorttengah(alist)
print(alist)

# %%
############################ T U G A S - P R A K T I K U M - 3 ############################

Tugas Praktikum 3

1.	Buatlah algoritma selection sort
    a.	Cari nilai minimum letakkan diposisi awal indeks
    b.	Cari nilai minimum letakkan diposisi akhir inddeks
    c.	Cari nilai maksimum dan letakkan diposisi awal indeks
    d.	Cari nilai maksimum dan letakkan diposisi akhir indeks 

2.	Implementasikan algoritma berikut ini
do
    swapped := false
    for each i in 0 to length( A ) - 2 do:
      if A[ i ] > A[ i + 1 ] then // test whether the two elements are in the wrong order
        swap( A[ i ], A[ i + 1 ] ) // let the two elements change places
        swapped := true
      end if
    end for
    if not swapped then
      // we can exit the outer loop here if no swaps occurred.
      break do-while loop
    end if
    swapped := false
    for each i in length( A ) - 2 to 0 do:
      if A[ i ] > A[ i + 1 ] then
        swap( A[ i ], A[ i + 1 ] )
        swapped := true
      end if
    end for
while swapped // if no elements have been swapped, then the list is sorted

3.	Bandingkan dengan algoritma no 2 dengan Bubble sort, manakah yang lebih efesien jika dihitung jumlah iterasinya.

# %%
# TP 3 (NO 1)
print("sellection short nilai minimum ke depan")
mylist = [12,23,54,45,13,11]
position = len(mylist)-1
for x in range (0,position) :
    min = x
    print(mylist)
    for y in range ((x+1),len(mylist)) :
        if mylist[min] > mylist[y] :
           min = y
    mylist[x],mylist[min] = mylist[min],mylist[x]
print(mylist)


print("sellection short nilai minimum ke belakang")
mylist = [12,23,54,45,13,11]
position = len(mylist)-1
for x in range (position,0,-1) :
    min = x
    print(mylist)
    for y in range (0,min,1) :
        if mylist[min] > mylist[y] :
            min = y
    mylist[x],mylist[min] = mylist[min],mylist[x]
print(mylist)


print("sellection short nilai maksimum ke depan")
mylist = [12,23,54,45,13,11]
position = len(mylist)-1
for x in range (0,position,1) :
    min = x
    print(mylist)
    for y in range ((x+1),len(mylist),1) :
        if mylist[min] < mylist[y] :
            min = y
    mylist[x],mylist[min] = mylist[min],mylist[x]
print(mylist)


print("sellection short nilai maksimum ke belakang")
mylist = [12,23,54,45,13,11]
position = len(mylist)-1
x = 0
for x in range (position,0,-1) :
    min = x
    print(mylist)
    for y in range (0,min,1) :
        if mylist[min] < mylist[y] :
            min = y
    mylist[x],mylist[min] = mylist[min],mylist[x]
print(mylist)

# %%
# TP 3 (NO 2)
a = [4,7,5,8,9,3,6,1,2,15]
print(a)
urut = False
henti = False
while not urut :
    swap = False
    for i in range (0,len(a)-1,1) :
        if a[i] > a[i+1] :
            a[i],a[i+1] = a[i+1],a[i]
            swap = True
            print(a)
    urut = True
    if swap == False :
        print("list sudah terurut")
        break

# %%
# TP 3 (N0 3)
mylist = [4,7,5,8,9,3,6,1,2,15]
iterasi = 0
for i in range (0,len(mylist)-1,1) :
    iterasi = iterasi + 1
    print(mylist)
    for y in range (i+1,len(mylist)) :
        if mylist[i] > mylist[y] :
            a = mylist[i]
            mylist[i] = mylist[y]
            mylist[y] = a
print (mylist)
print("iterasi ",iterasi)

# %%
            
            C.3 # Merge Sort
        Merge sort adalah algoritma rekursif yang terus-menerus membagi daftar menjadi dua.
    Jika daftar itu kosong atau memiliki satu item, itu diurutkan berdasarkan definisi (kasing dasar).
    Jika daftar memiliki lebih dari satu item, 
    kami membagi daftar dan secara rekursif memanggil semacam penggabungan pada kedua bagian. 
    Setelah kedua bagian diurutkan, operasi dasar, yang disebut gabungan, dilakukan.
    Penggabungan adalah proses mengambil dua daftar yang diurutkan lebih kecil dan menggabungkannya menjadi satu, 
    daftar yang baru, yang diurutkan.

# %%
# Contoh MergedSort 1
def MergedSort(A):
    n = len(A)
    if (n<2):
       return
    mid = len(A)//2
    left = A[:mid]
    right = A[mid:]
    MergedSort(left)
    MergedSort(right)
    i=0
    j=0
    k=0
    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            A[k]=left[i]
            i=i+1
        else:
            A[k]=right[j]
            j=j+1
        k=k+1

    while i < len(left):
        A[k]=left[i]
        i=i+1
        k=k+1

    while j < len(right):
        A[k]=right[j]
        j=j+1
        k=k+1

Alist= [54,26,93,17,99,77,31,44,55,20,100]
MergedSort(Alist)
print(Alist)

# %%
   
    C.4 # Shell Short
    
        Jenis shell, kadang-kadang disebut “sorting increment yang semakin berkurang,” 
    meningkatkan jenis sisipan dengan memecah daftar asli menjadi sejumlah sublists yang lebih kecil,
    yang masing-masing diurutkan menggunakan semacam sisipan.
    Cara unik yang dipilih sublists ini adalah kunci untuk jenis shell.
    Alih-alih memecah daftar menjadi sub daftar item yang berdekatan, jenis shell menggunakan kenaikan i, 
    kadang-kadang disebut celah, untuk membuat sublist dengan memilih semua item yang merupakan item i terpisah.

# %%
# Contoh Shell Sort 1
def shellSort(alist):
    sublistcount = len(alist)//2
    while sublistcount > 0:

      for startposition in range(sublistcount):
        print(sublistcount)
        gapInsertionSort(alist,startposition,sublistcount)
      sublistcount = sublistcount // 2

def gapInsertionSort(alist,start,gap):
    for i in range(start+gap,len(alist),gap):

        currentvalue = alist[i]
        position = i

        while position>=gap and alist[position-gap]>currentvalue:
            alist[position]=alist[position-gap]
            position = position-gap

        alist[position]=currentvalue
        print(alist)
        


alist = [35,33,42,10,14,19,27,44]
print(alist)
shellSort(alist)
print(alist)

# %%
############################ T U G A S - P R A K T I K U M - 4 ############################
Kelas E
1.	Buat modifikasi Insertion Sort, lakukan penggeserannya bukan kekiri tapi ke kanan, 
dengan membuat angka yang terurut secara menurun, jadi angka yang terkecil terletak di paling belakang.

68, 90, 78, 44, 34, 20, 100, 56, 34
68, 90, 78, 44, 34, 20, 100, 56, 34
68, 90, 78, 44, 34, 20, 100, 56, 34
68, 90, 78, 44, 34, 100, 56, 34, 20
Dst

2.	Modifikasi kode Quick Sort, jika pivotnya adalah terletak di middle
 
Dan buat agar urutan angkanya urutan menurun (seperti no 1)

3.	Modifikasi kode dalam Quick sort yang function def Partition(A,start,end) 
menjalankan seperti ilustrasi gambar dibawah ini

# %%
# TP 4 NO 1
a = [5,2,4,6,1,3]
for i in range (len(a)-2,-1,-1) :
    print(a)
    nilai = a[i]
    posisi = i
    while posisi < len(a)-1 and a[posisi + 1] > nilai :
        a[posisi] = a[posisi+1]
        posisi = posisi + 1
    a[posisi] = nilai
    
print(a)

# %%
# TP 4 NO 2
def quickSort(alist):
  quickSortHelper(alist,0,len(alist)-1)
def quickSortHelper(alist,start,end):
  if start >= end:
    return
  i,j = start,end
  pivot = (start + (end - start)//2)
  while i <= j  :
    while(alist[i] > alist[pivot]):
      i+=1
    while(alist[j] < alist[pivot]):
      j-=1
    if(i<=j):
      alist[i],alist[j] = alist[j],alist[i]
      i+=1
      j-=1
  quickSortHelper(alist,start,j)
  quickSortHelper(alist,i,end)
  return alist

alist = [34,56,78,90,32,12,65,45,76]

quickSort(alist)

print(alist)

# %%
# TP 4 NO 3 
def quicksort(a):
    quicksortawal(a,0,len(a)-1)

def quicksortawal(a,start,end) :
    i,j = start,end
    while i <= j :
        posisi = 1
        if i < i+1  :
            return
        elif i < j :
            return
        else :
            posisi = posisi + 1
   
    while i <= j :
        if i < posisi :
            i = a[posisi]
            i = i + 1
            if a[i] > [j] :
                a[i],a[j] = a[j],a[i]
                i = i + 1
                j = j - 1

    quicksortawal(alist,start,j)
    quicksortawal(alist,i,end)
    return a

a = [54,26,93,17,77,31,44,55,20]

quicksort(a)

print(a)
